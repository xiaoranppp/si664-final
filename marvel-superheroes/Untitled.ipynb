# %%
import pandas as pd
character=pd.read_csv('characters.csv')

# %%
c_name=list(character['name'])

# %%
info=pd.read_csv('marvel_characters_info.csv')

# %%
i_name=list(info['Name'])

# %%
print(len(c_name))
i=0
notin=[]
for name in i_name:
    if name not in c_name:
        notin.append(name)
        i=i+1
print(i,len(i_name))
# Out:
# 1170
# 513 734

# %%
import csv
with open('characters.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    c_list=[]
    for row in csv_reader:
        c_list.append(row)

# %%
namein=[]
num=[]
names=[]
for i in range(1,len(c_list)):
    if c_list[i][1] in i_name:
        namein.append(c_list[i])
        num.append(float(c_list[i][0]))
        names.append(c_list[i][1])

# %%
for name in i_name:
    if name not in names:
        temp=max(num)
        num.append(temp+1.0)
        names.append(name)
        namein.append([temp+1.0,name])

# %%
i_list=[]
with open('marvel_characters_info.csv') as csv_file1:
    csv_reader1 = csv.reader(csv_file1, delimiter=',')
    for row in csv_reader1:
        i_list.append(row)

# %%
newilist=[i_list[0]]
k=[]
for i in range(1,len(i_list)):
    if i_list[i][1] not in k:
        k.append(i_list[i][1])
        newilist.append(i_list[i])

# %%
newilist
# Out:
# [['ID',
#   'Name',
#   'Alignment',
#   'Gender',
#   'EyeColor',
#   'Race',
#   'HairColor',
#   'Publisher',
#   'SkinColor',
#   'Height',
#   'Weight'],
#  ['0',
#   'A-Bomb',
#   'good',
#   'Male',
#   'yellow',
#   'Human',
#   'No Hair',
#   'Marvel Comics',
#   '-',
#   '203',
#   '441'],
#  ['1',
#   'Abe Sapien',
#   'good',
#   'Male',
#   'blue',
#   'Icthyo Sapien',
#   'No Hair',
#   'Dark Horse Comics',
#   'blue',
#   '191',
#   '65'],
#  ['2',
#   'Abin Sur',
#   'good',
#   'Male',
#   'blue',
#   'Ungaran',
#   'No Hair',
#   'DC Comics',
#   'red',
#   '185',
#   '90'],
#  ['3',
#   'Abomination',
#   'bad',
#   'Male',
#   'green',
#   'Human / Radiation',
#   'No Hair',
#   'Marvel Comics',
#   '-',
#   '203',
#   '441'],
#  ['4',
#   'Abraxas',
#   'bad',
#   'Male',
#   'blue',
#   'Cosmic Entity',
#   'Black',
#   'Marvel Comics',
#   '-',
#   '-99',
#   '-99'],
#  ['5',
#   'Absorbing Man',
#   'bad',
#   'Male',
#   'blue',
#   'Human',
#   'No Hair',
# ...

# %%
names=sorted(names)
for i in range(1,716):
    print(names[i-1],newilist[i][1])
# Out:
# A-Bomb A-Bomb
# Abe Sapien Abe Sapien
# Abin Sur Abin Sur
# Abomination Abomination
# Abraxas Abraxas
# Absorbing Man Absorbing Man
# Adam Monroe Adam Monroe
# Adam Strange Adam Strange
# Agent 13 Agent 13
# Agent Bob Agent Bob
# Agent Zero Agent Zero
# Air-Walker Air-Walker
# Ajax Ajax
# Alan Scott Alan Scott
# Alex Mercer Alex Mercer
# Alex Woolsly Alex Woolsly
# Alfred Pennyworth Alfred Pennyworth
# Alien Alien
# Allan Quatermain Allan Quatermain
# Amazo Amazo
# Ammo Ammo
# Ando Masahashi Ando Masahashi
# Angel Angel
# Angel Dust Angel Dust
# Angel Salvadore Angel Salvadore
# Angela Angela
# Animal Man Animal Man
# Annihilus Annihilus
# Ant-Man Ant-Man
# Ant-Man II Ant-Man II
# Anti-Monitor Anti-Monitor
# Anti-Spawn Anti-Spawn
# Anti-Venom Anti-Venom
# Apocalypse Apocalypse
# Aquababy Aquababy
# Aqualad Aqualad
# Aquaman Aquaman
# Arachne Arachne
# Archangel Archangel
# Arclight Arclight
# Ardina Ardina
# Ares Ares
# Ariel Ariel
# Armor Armor
# Arsenal Arsenal
# ...

# %%
len(namein)
# Out:
# 716

# %%
for staff in i_list:
    if staff[1]=='JJ Powell':
        print(staff)
# Out:
# ['364', 'JJ Powell', 'good', 'Male', '-', '-', '-', 'ABC Studios', '-', '-99', '-99']

# %%
newilist.append(['364', 'JJ Powell', 'good', 'Male', '-', '-', '-', 'ABC Studios', '-', '-99', '-99'])

# %%
newilist=sorted(newilist, key=lambda student: student[0])

# %%
names=sorted(names)
for i in range(1,716):
    print(names[i-1],newilist[i][1])
# Out:
# A-Bomb Abe Sapien
# Abe Sapien Agent Zero
# Abin Sur Black Goliath
# Abomination Black Knight III
# Abraxas Black Lightning
# Absorbing Man Black Mamba
# Adam Monroe Black Manta
# Adam Strange Black Panther
# Agent 13 Black Widow
# Agent Bob Black Widow II
# Agent Zero Blackout
# Air-Walker Blackwing
# Ajax Air-Walker
# Alan Scott Blackwulf
# Alex Mercer Blade
# Alex Woolsly Blaquesmith
# Alfred Pennyworth Bling!
# Alien Blink
# Allan Quatermain Blizzard
# Amazo Blizzard II
# Ammo Blob
# Ando Masahashi Bloodaxe
# Angel Ajax
# Angel Dust Bloodhawk
# Angel Salvadore Bloodwraith
# Angela Blue Beetle
# Animal Man Blue Beetle II
# Annihilus Blue Beetle III
# Ant-Man Boba Fett
# Ant-Man II Bolt
# Anti-Monitor Bomb Queen
# Anti-Spawn Boom-Boom
# Anti-Venom Alan Scott
# Apocalypse Boomer
# Aquababy Booster Gold
# Aqualad Box
# Aquaman Box III
# Arachne Box IV
# Archangel Brainiac
# Arclight Brainiac 5
# Ardina Brother Voodoo
# Ares Brundlefly
# Ariel Buffy
# Armor Alex Mercer
# ...

# %%
names[0]
# Out:
# 'A-Bomb'

# %%
newilist
# Out:
# [['0',
#   'A-Bomb',
#   'good',
#   'Male',
#   'yellow',
#   'Human',
#   'No Hair',
#   'Marvel Comics',
#   '-',
#   '203',
#   '441'],
#  ['1',
#   'Abe Sapien',
#   'good',
#   'Male',
#   'blue',
#   'Icthyo Sapien',
#   'No Hair',
#   'Dark Horse Comics',
#   'blue',
#   '191',
#   '65'],
#  ['10',
#   'Agent Zero',
#   'good',
#   'Male',
#   '-',
#   '-',
#   '-',
#   'Marvel Comics',
#   '-',
#   '191',
#   '104'],
#  ['100',
#   'Black Goliath',
#   'good',
#   'Male',
#   '-',
#   '-',
#   '-',
#   'Marvel Comics',
#   '-',
#   '-99',
#   '-99'],
#  ['101',
#   'Black Knight III',
#   'good',
#   'Male',
#   'brown',
#   'Human',
#   'Brown',
#   'Marvel Comics',
#   '-',
#   '183',
#   '86'],
#  ['102',
#   'Black Lightning',
#   'good',
#   'Male',
#   'brown',
#   '-',
#   'No Hair',
#   'DC Comics',
#   '-',
#   '185',
#   '90'],
#  ['103',
#   'Black Mamba',
#   'bad',
#   'Female',
#   'green',
#   '-',
#   'Black',
#   'Marvel Comics',
#   '-',
#   '170',
# ...

# %%
k=newilist[-1]

# %%
newilist.remove(k)

# %%
newilist=[k]+newilist

# %%
names=sorted(names)
for i in range(1,716):
    print(names[i-1],newilist[i][1])
# Out:
# A-Bomb A-Bomb
# Abe Sapien Abe Sapien
# Abin Sur Agent Zero
# Abomination Black Goliath
# Abraxas Black Knight III
# Absorbing Man Black Lightning
# Adam Monroe Black Mamba
# Adam Strange Black Manta
# Agent 13 Black Panther
# Agent Bob Black Widow
# Agent Zero Black Widow II
# Air-Walker Blackout
# Ajax Blackwing
# Alan Scott Air-Walker
# Alex Mercer Blackwulf
# Alex Woolsly Blade
# Alfred Pennyworth Blaquesmith
# Alien Bling!
# Allan Quatermain Blink
# Amazo Blizzard
# Ammo Blizzard II
# Ando Masahashi Blob
# Angel Bloodaxe
# Angel Dust Ajax
# Angel Salvadore Bloodhawk
# Angela Bloodwraith
# Animal Man Blue Beetle
# Annihilus Blue Beetle II
# Ant-Man Blue Beetle III
# Ant-Man II Boba Fett
# Anti-Monitor Bolt
# Anti-Spawn Bomb Queen
# Anti-Venom Boom-Boom
# Apocalypse Alan Scott
# Aquababy Boomer
# Aqualad Booster Gold
# Aquaman Box
# Arachne Box III
# Archangel Box IV
# Arclight Brainiac
# Ardina Brainiac 5
# Ares Brother Voodoo
# Ariel Brundlefly
# Armor Buffy
# ...

# %%
len(newilist)
# Out:
# 717

# %%
len(names)
# Out:
# 716

# %%
newilist.remove(newilist[0])

# %%
newilist=sorted(newilist, key=lambda student: student[1])

# %%
newilist
# Out:
# [['0',
#   'A-Bomb',
#   'good',
#   'Male',
#   'yellow',
#   'Human',
#   'No Hair',
#   'Marvel Comics',
#   '-',
#   '203',
#   '441'],
#  ['1',
#   'Abe Sapien',
#   'good',
#   'Male',
#   'blue',
#   'Icthyo Sapien',
#   'No Hair',
#   'Dark Horse Comics',
#   'blue',
#   '191',
#   '65'],
#  ['2',
#   'Abin Sur',
#   'good',
#   'Male',
#   'blue',
#   'Ungaran',
#   'No Hair',
#   'DC Comics',
#   'red',
#   '185',
#   '90'],
#  ['3',
#   'Abomination',
#   'bad',
#   'Male',
#   'green',
#   'Human / Radiation',
#   'No Hair',
#   'Marvel Comics',
#   '-',
#   '203',
#   '441'],
#  ['4',
#   'Abraxas',
#   'bad',
#   'Male',
#   'blue',
#   'Cosmic Entity',
#   'Black',
#   'Marvel Comics',
#   '-',
#   '-99',
#   '-99'],
#  ['5',
#   'Absorbing Man',
#   'bad',
#   'Male',
#   'blue',
#   'Human',
#   'No Hair',
#   'Marvel Comics',
#   '-',
#   '193',
#   '122'],
#  ['6',
#   'Adam Monroe',
#   'good',
#   'Male',
#   'blue',
#   '-',
#   'Blond',
#   'NBC - Heroes',
# ...

# %%
newilist=[k]+newilist

# %%
names=sorted(names)
for i in range(1,716):
    print(names[i-1],newilist[i][1])
# Out:
# A-Bomb A-Bomb
# Abe Sapien Abe Sapien
# Abin Sur Abin Sur
# Abomination Abomination
# Abraxas Abraxas
# Absorbing Man Absorbing Man
# Adam Monroe Adam Monroe
# Adam Strange Adam Strange
# Agent 13 Agent 13
# Agent Bob Agent Bob
# Agent Zero Agent Zero
# Air-Walker Air-Walker
# Ajax Ajax
# Alan Scott Alan Scott
# Alex Mercer Alex Mercer
# Alex Woolsly Alex Woolsly
# Alfred Pennyworth Alfred Pennyworth
# Alien Alien
# Allan Quatermain Allan Quatermain
# Amazo Amazo
# Ammo Ammo
# Ando Masahashi Ando Masahashi
# Angel Angel
# Angel Dust Angel Dust
# Angel Salvadore Angel Salvadore
# Angela Angela
# Animal Man Animal Man
# Annihilus Annihilus
# Ant-Man Ant-Man
# Ant-Man II Ant-Man II
# Anti-Monitor Anti-Monitor
# Anti-Spawn Anti-Spawn
# Anti-Venom Anti-Venom
# Apocalypse Apocalypse
# Aquababy Aquababy
# Aqualad Aqualad
# Aquaman Aquaman
# Arachne Arachne
# Archangel Archangel
# Arclight Arclight
# Ardina Ardina
# Ares Ares
# Ariel Ariel
# Armor Armor
# Arsenal Arsenal
# ...

# %%
len(namein)
# Out:
# 716

# %%
len(names)
# Out:
# 716

# %%
namein
# Out:
# [['1009220', 'Captain America'],
#  ['1010740', 'Winter Soldier'],
#  ['1009471', 'Nick Fury'],
#  ['1009515', 'Punisher'],
#  ['1009535', 'Red Skull'],
#  ['1009175', 'Beast'],
#  ['1009243', 'Colossus'],
#  ['1009257', 'Cyclops'],
#  ['1009310', 'Emma Frost'],
#  ['1009718', 'Wolverine'],
#  ['1009610', 'Spider-Man'],
#  ['1009368', 'Iron Man'],
#  ['1009268', 'Deadpool'],
#  ['1009313', 'Gambit'],
#  ['1009546', 'Rogue'],
#  ['1009378', 'Jessica Jones'],
#  ['1009215', 'Luke Cage'],
#  ['1009277', 'Domino'],
#  ['1009393', 'Lady Deathstrike'],
#  ['1009482', 'Omega Red'],
#  ['1009554', 'Sabretooth'],
#  ['1009705', 'Warpath'],
#  ['1009312', 'Galactus'],
#  ['1009592', 'Silver Surfer'],
#  ['1009168', 'Banshee'],
#  ['1009267', 'Dazzler'],
#  ['1009337', 'Havok'],
#  ['1009351', 'Hulk'],
#  ['1010805', 'Machine Man'],
#  ['1009512', 'Psylocke'],
#  ['1009472', 'Nightcrawler'],
#  ['1009629', 'Storm'],
#  ['1009327', 'Jean Grey'],
#  ['1009281', 'Doctor Doom'],
# ...

# %%
for staff in c_list:
    if "Jean Grey" in staff:
        namein.append(staff)
    if staff[1]=='Jean-Luc Picard':
        namein.append(staff)

# %%
namein=sorted(namein, key=lambda student: student[1])

# %%
len(namein)
# Out:
# 715

# %%
len(newilist)
# Out:
# 716

# %%
for i in range(715):
    print(namein[i][1],newilist[i+1][1],i)
# Out:
# A-Bomb A-Bomb 0
# Abe Sapien Abe Sapien 1
# Abin Sur Abin Sur 2
# Abomination Abomination 3
# Abraxas Abraxas 4
# Absorbing Man Absorbing Man 5
# Adam Monroe Adam Monroe 6
# Adam Strange Adam Strange 7
# Agent 13 Agent 13 8
# Agent Bob Agent Bob 9
# Agent Zero Agent Zero 10
# Air-Walker Air-Walker 11
# Ajax Ajax 12
# Alan Scott Alan Scott 13
# Alex Mercer Alex Mercer 14
# Alex Woolsly Alex Woolsly 15
# Alfred Pennyworth Alfred Pennyworth 16
# Alien Alien 17
# Allan Quatermain Allan Quatermain 18
# Amazo Amazo 19
# Ammo Ammo 20
# Ando Masahashi Ando Masahashi 21
# Angel Angel 22
# Angel Dust Angel Dust 23
# Angel Salvadore Angel Salvadore 24
# Angela Angela 25
# Animal Man Animal Man 26
# Annihilus Annihilus 27
# Ant-Man Ant-Man 28
# Ant-Man II Ant-Man II 29
# Anti-Monitor Anti-Monitor 30
# Anti-Spawn Anti-Spawn 31
# Anti-Venom Anti-Venom 32
# Apocalypse Apocalypse 33
# Aquababy Aquababy 34
# Aqualad Aqualad 35
# Aquaman Aquaman 36
# Arachne Arachne 37
# Archangel Archangel 38
# ...

# %%
newilist.remove(newilist[335])

# %%
for staff in i_list:
    if staff[1]=='Isis':
        newilist.append(staff)

# %%
newilist=sorted(newilist, key=lambda student: student[1]) 
for i in range(715):
    print(namein[i][1],newilist[i][1],i)
# Out:
# A-Bomb A-Bomb 0
# Abe Sapien Abe Sapien 1
# Abin Sur Abin Sur 2
# Abomination Abomination 3
# Abraxas Abraxas 4
# Absorbing Man Absorbing Man 5
# Adam Monroe Adam Monroe 6
# Adam Strange Adam Strange 7
# Agent 13 Agent 13 8
# Agent Bob Agent Bob 9
# Agent Zero Agent Zero 10
# Air-Walker Air-Walker 11
# Ajax Ajax 12
# Alan Scott Alan Scott 13
# Alex Mercer Alex Mercer 14
# Alex Woolsly Alex Woolsly 15
# Alfred Pennyworth Alfred Pennyworth 16
# Alien Alien 17
# Allan Quatermain Allan Quatermain 18
# Amazo Amazo 19
# Ammo Ammo 20
# Ando Masahashi Ando Masahashi 21
# Angel Angel 22
# Angel Dust Angel Dust 23
# Angel Salvadore Angel Salvadore 24
# Angela Angela 25
# Animal Man Animal Man 26
# Annihilus Annihilus 27
# Ant-Man Ant-Man 28
# Ant-Man II Ant-Man II 29
# Anti-Monitor Anti-Monitor 30
# Anti-Spawn Anti-Spawn 31
# Anti-Venom Anti-Venom 32
# Apocalypse Apocalypse 33
# Aquababy Aquababy 34
# Aqualad Aqualad 35
# Aquaman Aquaman 36
# Arachne Arachne 37
# Archangel Archangel 38
# ...

# %%
k=newilist[469]
newilist.remove(k)

# %%
newilist=sorted(newilist, key=lambda student: student[1]) 
for i in range(715):
  #  if namein[i][1]!=newilist[i][1]:
        print(namein[i][1],newilist[i][1],i)
# Out:
# A-Bomb A-Bomb 0
# Abe Sapien Abe Sapien 1
# Abin Sur Abin Sur 2
# Abomination Abomination 3
# Abraxas Abraxas 4
# Absorbing Man Absorbing Man 5
# Adam Monroe Adam Monroe 6
# Adam Strange Adam Strange 7
# Agent 13 Agent 13 8
# Agent Bob Agent Bob 9
# Agent Zero Agent Zero 10
# Air-Walker Air-Walker 11
# Ajax Ajax 12
# Alan Scott Alan Scott 13
# Alex Mercer Alex Mercer 14
# Alex Woolsly Alex Woolsly 15
# Alfred Pennyworth Alfred Pennyworth 16
# Alien Alien 17
# Allan Quatermain Allan Quatermain 18
# Amazo Amazo 19
# Ammo Ammo 20
# Ando Masahashi Ando Masahashi 21
# Angel Angel 22
# Angel Dust Angel Dust 23
# Angel Salvadore Angel Salvadore 24
# Angela Angela 25
# Animal Man Animal Man 26
# Annihilus Annihilus 27
# Ant-Man Ant-Man 28
# Ant-Man II Ant-Man II 29
# Anti-Monitor Anti-Monitor 30
# Anti-Spawn Anti-Spawn 31
# Anti-Venom Anti-Venom 32
# Apocalypse Apocalypse 33
# Aquababy Aquababy 34
# Aqualad Aqualad 35
# Aquaman Aquaman 36
# Arachne Arachne 37
# Archangel Archangel 38
# ...

# %%
newilist.remove(newilist[335])
for staff in i_list:
    if staff[1]=='Iron Monger':
        newilist.append(staff)

# %%
newilist=sorted(newilist, key=lambda student: student[1]) 
for i in range(715):
    #if namein[i][1]!=newilist[i][1]:
        print(namein[i][1],newilist[i][1],i)
# Out:
# A-Bomb A-Bomb 0
# Abe Sapien Abe Sapien 1
# Abin Sur Abin Sur 2
# Abomination Abomination 3
# Abraxas Abraxas 4
# Absorbing Man Absorbing Man 5
# Adam Monroe Adam Monroe 6
# Adam Strange Adam Strange 7
# Agent 13 Agent 13 8
# Agent Bob Agent Bob 9
# Agent Zero Agent Zero 10
# Air-Walker Air-Walker 11
# Ajax Ajax 12
# Alan Scott Alan Scott 13
# Alex Mercer Alex Mercer 14
# Alex Woolsly Alex Woolsly 15
# Alfred Pennyworth Alfred Pennyworth 16
# Alien Alien 17
# Allan Quatermain Allan Quatermain 18
# Amazo Amazo 19
# Ammo Ammo 20
# Ando Masahashi Ando Masahashi 21
# Angel Angel 22
# Angel Dust Angel Dust 23
# Angel Salvadore Angel Salvadore 24
# Angela Angela 25
# Animal Man Animal Man 26
# Annihilus Annihilus 27
# Ant-Man Ant-Man 28
# Ant-Man II Ant-Man II 29
# Anti-Monitor Anti-Monitor 30
# Anti-Spawn Anti-Spawn 31
# Anti-Venom Anti-Venom 32
# Apocalypse Apocalypse 33
# Aquababy Aquababy 34
# Aqualad Aqualad 35
# Aquaman Aquaman 36
# Arachne Arachne 37
# Archangel Archangel 38
# ...

# %%
for staff in c_list:
    if staff[1]=='Jean-Luc Picard':
        namein.append(staff)
namein=sorted(namein, key=lambda student: student[1])

# %%
for i in range(715):
    #if namein[i][1]!=newilist[i][1]:
        print(namein[i][1],newilist[i][1],i)
# Out:
# A-Bomb A-Bomb 0
# Abe Sapien Abe Sapien 1
# Abin Sur Abin Sur 2
# Abomination Abomination 3
# Abraxas Abraxas 4
# Absorbing Man Absorbing Man 5
# Adam Monroe Adam Monroe 6
# Adam Strange Adam Strange 7
# Agent 13 Agent 13 8
# Agent Bob Agent Bob 9
# Agent Zero Agent Zero 10
# Air-Walker Air-Walker 11
# Ajax Ajax 12
# Alan Scott Alan Scott 13
# Alex Mercer Alex Mercer 14
# Alex Woolsly Alex Woolsly 15
# Alfred Pennyworth Alfred Pennyworth 16
# Alien Alien 17
# Allan Quatermain Allan Quatermain 18
# Amazo Amazo 19
# Ammo Ammo 20
# Ando Masahashi Ando Masahashi 21
# Angel Angel 22
# Angel Dust Angel Dust 23
# Angel Salvadore Angel Salvadore 24
# Angela Angela 25
# Animal Man Animal Man 26
# Annihilus Annihilus 27
# Ant-Man Ant-Man 28
# Ant-Man II Ant-Man II 29
# Anti-Monitor Anti-Monitor 30
# Anti-Spawn Anti-Spawn 31
# Anti-Venom Anti-Venom 32
# Apocalypse Apocalypse 33
# Aquababy Aquababy 34
# Aqualad Aqualad 35
# Aquaman Aquaman 36
# Arachne Arachne 37
# Archangel Archangel 38
# ...

# %%
len(newilist)
# Out:
# 715

# %%
for staff in c_list:
    if staff[1]=='Jean-Luc Picard':
        print(staff)

# %%
newilist.remove(newilist[345])
namein.remove(namein[345])

# %%
for i in range(714):
    if namein[i][1]!=newilist[i][1]:
        print(namein[i][1],newilist[i][1],i)
    else:
        newilist[i].append(namein[i][0])

# %%
k.append('Number')

# %%
for i in range(len(newilist)):
     newilist[i][-1]=str(int(newilist[i][-1]))

# %%
s_list=[]
with open('charcters_stats.csv') as csv_file2:
    csv_reader2 = csv.reader(csv_file2, delimiter=',')
    for row in csv_reader2:
        s_list.append(row)

# %%
s_list
# Out:
# [['Name',
#   'Alignment',
#   'Intelligence',
#   'Strength',
#   'Speed',
#   'Durability',
#   'Power',
#   'Combat',
#   'Total'],
#  ['3-D Man', 'good', '50', '31', '43', '32', '25', '52', '233'],
#  ['A-Bomb', 'good', '38', '100', '17', '80', '17', '64', '316'],
#  ['Abe Sapien', 'good', '88', '14', '35', '42', '35', '85', '299'],
#  ['Abin Sur', 'good', '50', '90', '53', '64', '84', '65', '406'],
#  ['Abomination', 'bad', '63', '80', '53', '90', '55', '95', '436'],
#  ['Abraxas', 'bad', '88', '100', '83', '99', '100', '56', '526'],
#  ['Adam Monroe', 'good', '63', '10', '12', '100', '71', '64', '320'],
#  ['Adam Strange', 'good', '1', '1', '1', '1', '0', '1', '5'],
#  ['Agent  13', 'good', '1', '1', '1', '1', '0', '1', '5'],
#  ['Agent Bob', 'good', '10', '8', '13', '5', '5', '20', '61'],
#  ['Agent Zero', 'good', '75', '28', '38', '80', '72', '95', '388'],
#  ['Air-Walker', 'bad', '50', '85', '100', '85', '100', '40', '460'],
# ...

# %%
k=k+['Alignment',
  'Intelligence',
  'Strength',
  'Speed',
  'Durability',
  'Power',
  'Combat',
  'Total']

# %%
k
# Out:
# ['ID',
#  'Name',
#  'Alignment',
#  'Gender',
#  'EyeColor',
#  'Race',
#  'HairColor',
#  'Publisher',
#  'SkinColor',
#  'Height',
#  'Weight',
#  'Number',
#  'Alignment',
#  'Intelligence',
#  'Strength',
#  'Speed',
#  'Durability',
#  'Power',
#  'Combat',
#  'Total']

# %%
name=[]
for n in newilist:
    name.append(n[1])

# %%
name
# Out:
# ['A-Bomb',
#  'Abe Sapien',
#  'Abin Sur',
#  'Abomination',
#  'Abraxas',
#  'Absorbing Man',
#  'Adam Monroe',
#  'Adam Strange',
#  'Agent 13',
#  'Agent Bob',
#  'Agent Zero',
#  'Air-Walker',
#  'Ajax',
#  'Alan Scott',
#  'Alex Mercer',
#  'Alex Woolsly',
#  'Alfred Pennyworth',
#  'Alien',
#  'Allan Quatermain',
#  'Amazo',
#  'Ammo',
#  'Ando Masahashi',
#  'Angel',
#  'Angel Dust',
#  'Angel Salvadore',
#  'Angela',
#  'Animal Man',
#  'Annihilus',
#  'Ant-Man',
#  'Ant-Man II',
#  'Anti-Monitor',
#  'Anti-Spawn',
#  'Anti-Venom',
#  'Apocalypse',
#  'Aquababy',
#  'Aqualad',
#  'Aquaman',
#  'Arachne',
#  'Archangel',
#  'Arclight',
#  'Ardina',
#  'Ares',
#  'Ariel',
#  'Armor',
#  'Arsenal',
#  'Astro Boy',
#  'Atlas',
#  'Atom',
#  'Atom Girl',
#  'Atom II',
#  'Atom III',
#  'Atom IV',
#  'Aurora',
#  'Azazel',
#  'Azrael',
#  'Aztar',
#  'Bane',
#  'Banshee',
#  'Bantam',
#  'Batgirl',
#  'Batgirl III',
#  'Batgirl IV',
#  'Batgirl V',
#  'Batgirl VI',
#  'Batman',
# ...

# %%
for staff in s_list:
    if staff[0] in name:
        nm=name.index(staff[0])
        temp=staff[1:]
        newilist[nm]=newilist[nm]+temp

# %%
newilist[-1]=['733',
 'Zoom',
 'bad',
 'Male',
 'red',
 '-',
 'Brown',
 'DC Comics',
 '-',
 '185',
 '81','1011929']

# %%
for staff in newilist:
    if len(staff)!=20:
        print(staff)
# Out:
# ['5', 'Absorbing Man', 'bad', 'Male', 'blue', 'Human', 'No Hair', 'Marvel Comics', '-', '193', '122', '1009148']
# ['8', 'Agent 13', 'good', 'Female', 'blue', '-', 'Blond', 'Marvel Comics', '-', '173', '61', '1011436']
# ['12', 'Ajax', 'bad', 'Male', 'brown', 'Cyborg', 'Black', 'Marvel Comics', '-', '193', '90', '1011439']
# ['14', 'Alex Mercer', 'bad', 'Male', '-', 'Human', '-', 'Wildstorm', '-', '-99', '-99', '1011441']
# ['17', 'Alien', 'bad', 'Male', '-', 'Xenomorph XX121', 'No Hair', 'Dark Horse Comics', 'black', '244', '169', '1011444']
# ['24', 'Angel Dust', 'good', 'Female', 'yellow', 'Mutant', 'Black', 'Marvel Comics', '-', '165', '57', '1011450']
# ['41', 'Ardina', 'good', 'Female', 'white', 'Alien', 'Orange', 'Marvel Comics', 'gold', '193', '98', '1011462']
# ['62', 'Batgirl', 'good', 'Female', '-', '-', '-', 'DC Comics', '-', '-99', '-99', '1011478']
# ['72', 'Batwoman V', 'good', 'Female', 'green', 'Human', 'Red', 'DC Comics', '-', '178', '-99', '1011486']
# ...

# %%
for i in range(len(newilist)):
    if len(newilist[i])!=20:
        newilist[i]=newilist[i]+['-','-','-','-','-','-','-','-']

# %%
ll=[1]
ll+['-','-','-','-','-','-','-','-']
# Out:
# [1, '-', '-', '-', '-', '-', '-', '-', '-']

# %%
for i in range(len(newilist)):
    if len(newilist[i])!=20:
        print(i)
# Out:
# 482

# %%
newilist[482]=['496',
 'Nova',
 'good',
 'Male',
 'brown',
 'Human',
 'Brown',
 'Marvel Comics',
 '-',
 '185',
 '86',
 '1009477',
 'good',
 '100',
 '85',
 '67',
 '101',
 '100',
 '85',
 '538']

# %%
for i in range(len(newilist)):
    if len(newilist[i])!=20:
        print(i)

# %%
len(k)
# Out:
# 20

# %%
newilist=k+newilist

# %%
newilist
# Out:
# ['ID',
#  'Name',
#  'Alignment',
#  'Gender',
#  'EyeColor',
#  'Race',
#  'HairColor',
#  'Publisher',
#  'SkinColor',
#  'Height',
#  'Weight',
#  'Number',
#  'Alignment',
#  'Intelligence',
#  'Strength',
#  'Speed',
#  'Durability',
#  'Power',
#  'Combat',
#  'Total',
#  ['0',
#   'A-Bomb',
#   'good',
#   'Male',
#   'yellow',
#   'Human',
#   'No Hair',
#   'Marvel Comics',
#   '-',
#   '203',
#   '441',
#   '1011429',
#   'good',
#   '38',
#   '100',
#   '17',
#   '80',
#   '17',
#   '64',
#   '316'],
#  ['1',
#   'Abe Sapien',
#   'good',
#   'Male',
#   'blue',
#   'Icthyo Sapien',
#   'No Hair',
#   'Dark Horse Comics',
#   'blue',
#   '191',
#   '65',
#   '1011430',
#   'good',
#   '88',
#   '14',
#   '35',
#   '42',
#   '35',
#   '85',
#   '299'],
#  ['2',
#   'Abin Sur',
#   'good',
#   'Male',
#   'blue',
#   'Ungaran',
#   'No Hair',
#   'DC Comics',
#   'red',
#   '185',
#   '90',
#   '1011431',
#   'good',
#   '50',
#   '90',
#   '53',
#   '64',
#   '84',
# ...

# %%
for staff in k:
    newilist.remove(staff)

# %%
newilist=[k]+newilist

# %%
for i in range(1,len(newilist)):
    newilist[i][0]=str(i)

# %%
newilist[-1]
# Out:
# ['714',
#  'Zoom',
#  'bad',
#  'Male',
#  'red',
#  '-',
#  'Brown',
#  'DC Comics',
#  '-',
#  '185',
#  '81',
#  '1011929',
#  'bad',
#  '50',
#  '10',
#  '100',
#  '28',
#  '72',
#  '28',
#  '288']

# %%
name=k
newilist.remove(newilist[0])
test=pd.DataFrame(columns=name,data=newilist)#数据有三列，列名分别为one,two,three
test.to_csv('testcsv.csv',encoding='gbk')

# %%
with open('character_total1.csv', 'w', newline=',') as myfile:
        wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
        wr.writerow(newilist)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-175-c5d7f0bb2ea6> in <module>()
# ----> 1 with open('character_total1.csv', 'w', newline=',') as myfile:
#       2         wr = csv.writer(myfile, quoting=csv.QUOTE_ALL)
#       3         wr.writerow(newilist)
#
# ValueError: illegal newline value: ,

# %%
people=[]
for staff in power:
